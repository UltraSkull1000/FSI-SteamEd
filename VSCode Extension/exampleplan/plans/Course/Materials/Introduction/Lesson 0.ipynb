# %% [markdown]
# # Lesson 0: Hello World
#
# Before we dive into the deep end, it's time for right of passage. It's the classic hello world program. It's a truly simple one line code masterpiece:

# %%
print("Hello World")

# %% [markdown]
# You'll notice that there are 2 parts to this the `print()` and the `"Hello World"`. `Print()` is function, that when you put string like `"Hello World"` it'll print it to the screen. The quotation marks around `"Hello World"` are very important, without them, the code will not work. Don't worry to much about the Strings and functions we'll cover it in more detail later, for now just try writing `Hello World` or your own message in between the quotation marks.

# %% [markdown]
# ## Running the code
# Now that we have code let's run it! To run a program go ahead and hit the play button towards the to right of screen. You should see a new screen on the bottom appear, and if you did it correctly you should see your message. Well done! If you got an error, that's OK!
#
# In every lesson you'll find advice for handling these sort of errors in our "Bugs and Issues" section. It's also worth noting that programming isn't getting right on your first try it's about solving problems, so it's OK if things go wrong.

# %% [markdown]
# ## Bugs and Issues
# In each of the chapters you'll find a section like this which will cover the common bugs and issues when trying to solve or understand the content. In this section the code is very simple so the shouldn't be any problems, just make sure that you spelled `print()` correctly and used quotation marks around your message. Don't include anything else.
